# %%
import numpy as np
import pandas as pd

# %%
parquet_path = "/home/kinisi/Documents/main/lerobot-bimanual/custom_scripts/analysis/data/pranavnaik98/bimanual_so101_stacking_100/data/chunk-000/file-001.parquet"
df = pd.read_parquet(path=parquet_path)

# %% [markdown]
# The parquet files dataset/data dir is expected to have the following features, <br>
# `action`, `episode_index`, `frame_index`, <br>
# `index`, `timestamp`, `task_index`
#
# There are also 2 other params namely `from_index` and `to_iceberg` - curious !!!

# %%
# colums: ["action", "observation.state", "timestamp", "frame_index", "episode_index", "index", "task_index"]
for column_name in df.columns:
    column_data = df[column_name]
    print(f"{column_name}.shape = {column_data.shape}")
# Out:
# action.shape = (59988,)
# observation.state.shape = (59988,)
# timestamp.shape = (59988,)
# frame_index.shape = (59988,)
# episode_index.shape = (59988,)
# index.shape = (59988,)
# task_index.shape = (59988,)

# %%
import numpy as np

# Convert the column of arrays into a single 2D NumPy array
# This turns (4800,) of arrays into (4800, 12)
actions = np.stack(df['action'].values)
states = np.stack(df['observation.state'].values)

# Split into Left and Right (assuming first 6 are Left, next 6 are Right)
left_arm_action = actions[:, :6]
right_arm_action = actions[:, 6:]

print(f"Left Arm Action Shape: {left_arm_action.shape}") # Expected: (4800, 6)
# Out:
# Left Arm Action Shape: (4800, 6)

# %%
meta_parquet_path = "/home/kinisi/Documents/main/lerobot-bimanual/custom_scripts/analysis/data/pranavnaik98/bimanual_so101_stacking_100/meta/episodes/chunk-000/file-000.parquet"
mdf = pd.read_parquet(meta_parquet_path)

# colums: ["action", "observation.state", "timestamp", "frame_index", "episode_index", "index", "task_index"]
for column_name in mdf.columns:
    column_data = mdf[column_name]
    print(f"{column_name}.shape = {column_data.shape}")
# Out:
# episode_index.shape = (8,)
# tasks.shape = (8,)
# length.shape = (8,)
# data/chunk_index.shape = (8,)
# data/file_index.shape = (8,)
# dataset_from_index.shape = (8,)
# dataset_to_index.shape = (8,)
# videos/observation.images.top/chunk_index.shape = (8,)
# videos/observation.images.top/file_index.shape = (8,)
# videos/observation.images.top/from_timestamp.shape = (8,)
# videos/observation.images.top/to_timestamp.shape = (8,)
# videos/observation.images.front/chunk_index.shape = (8,)
# videos/observation.images.front/file_index.shape = (8,)
# videos/observation.images.front/from_timestamp.shape = (8,)
# videos/observation.images.front/to_timestamp.shape = (8,)
# stats/action/min.shape = (8,)
# stats/action/max.shape = (8,)
# stats/action/mean.shape = (8,)
# stats/action/std.shape = (8,)
# stats/action/count.shape = (8,)
# stats/action/q01.shape = (8,)
# stats/action/q10.shape = (8,)
# stats/action/q50.shape = (8,)
# stats/action/q90.shape = (8,)
# stats/action/q99.shape = (8,)
# stats/observation.state/min.shape = (8,)
# stats/observation.state/max.shape = (8,)
# stats/observation.state/mean.shape = (8,)
# stats/observation.state/std.shape = (8,)
# stats/observation.state/count.shape = (8,)
# stats/observation.state/q01.shape = (8,)
# stats/observation.state/q10.shape = (8,)
# stats/observation.state/q50.shape = (8,)
# stats/observation.state/q90.shape = (8,)
# stats/observation.state/q99.shape = (8,)
# stats/observation.images.top/min.shape = (8,)
# stats/observation.images.top/max.shape = (8,)
# stats/observation.images.top/mean.shape = (8,)
# stats/observation.images.top/std.shape = (8,)
# stats/observation.images.top/count.shape = (8,)
# stats/observation.images.top/q01.shape = (8,)
# stats/observation.images.top/q10.shape = (8,)
# stats/observation.images.top/q50.shape = (8,)
# stats/observation.images.top/q90.shape = (8,)
# stats/observation.images.top/q99.shape = (8,)
# stats/observation.images.front/min.shape = (8,)
# stats/observation.images.front/max.shape = (8,)
# stats/observation.images.front/mean.shape = (8,)
# stats/observation.images.front/std.shape = (8,)
# stats/observation.images.front/count.shape = (8,)
# stats/observation.images.front/q01.shape = (8,)
# stats/observation.images.front/q10.shape = (8,)
# stats/observation.images.front/q50.shape = (8,)
# stats/observation.images.front/q90.shape = (8,)
# stats/observation.images.front/q99.shape = (8,)
# stats/timestamp/min.shape = (8,)
# stats/timestamp/max.shape = (8,)
# stats/timestamp/mean.shape = (8,)
# stats/timestamp/std.shape = (8,)
# stats/timestamp/count.shape = (8,)
# stats/timestamp/q01.shape = (8,)
# stats/timestamp/q10.shape = (8,)
# stats/timestamp/q50.shape = (8,)
# stats/timestamp/q90.shape = (8,)
# stats/timestamp/q99.shape = (8,)
# stats/frame_index/min.shape = (8,)
# stats/frame_index/max.shape = (8,)
# stats/frame_index/mean.shape = (8,)
# stats/frame_index/std.shape = (8,)
# stats/frame_index/count.shape = (8,)
# stats/frame_index/q01.shape = (8,)
# stats/frame_index/q10.shape = (8,)
# stats/frame_index/q50.shape = (8,)
# stats/frame_index/q90.shape = (8,)
# stats/frame_index/q99.shape = (8,)
# stats/episode_index/min.shape = (8,)
# stats/episode_index/max.shape = (8,)
# stats/episode_index/mean.shape = (8,)
# stats/episode_index/std.shape = (8,)
# stats/episode_index/count.shape = (8,)
# stats/episode_index/q01.shape = (8,)
# stats/episode_index/q10.shape = (8,)
# stats/episode_index/q50.shape = (8,)
# stats/episode_index/q90.shape = (8,)
# stats/episode_index/q99.shape = (8,)
# stats/index/min.shape = (8,)
# stats/index/max.shape = (8,)
# stats/index/mean.shape = (8,)
# stats/index/std.shape = (8,)
# stats/index/count.shape = (8,)
# stats/index/q01.shape = (8,)
# stats/index/q10.shape = (8,)
# stats/index/q50.shape = (8,)
# stats/index/q90.shape = (8,)
# stats/index/q99.shape = (8,)
# stats/task_index/min.shape = (8,)
# stats/task_index/max.shape = (8,)
# stats/task_index/mean.shape = (8,)
# stats/task_index/std.shape = (8,)
# stats/task_index/count.shape = (8,)
# stats/task_index/q01.shape = (8,)
# stats/task_index/q10.shape = (8,)
# stats/task_index/q50.shape = (8,)
# stats/task_index/q90.shape = (8,)
# stats/task_index/q99.shape = (8,)
# meta/episodes/chunk_index.shape = (8,)
# meta/episodes/file_index.shape = (8,)

# %%
from lerobot.datasets.lerobot_dataset import LeRobotDataset
src = LeRobotDataset(
        repo_id="pranavnaik98/bimanual_so101_stacking_100",
        root="/home/kinisi/Documents/main/lerobot-bimanual/custom_scripts/analysis/data/pranavnaik98/bimanual_so101_stacking_100",
        video_backend="pyav",
    )

# %%
src.meta.features
# Out:
# {'action': {'dtype': 'float32',
#   'names': ['left_shoulder_pan.pos',
#    'left_shoulder_lift.pos',
#    'left_elbow_flex.pos',
#    'left_wrist_flex.pos',
#    'left_wrist_roll.pos',
#    'left_gripper.pos',
#    'right_shoulder_pan.pos',
#    'right_shoulder_lift.pos',
#    'right_elbow_flex.pos',
#    'right_wrist_flex.pos',
#    'right_wrist_roll.pos',
#    'right_gripper.pos'],
#   'shape': (12,)},
#  'observation.state': {'dtype': 'float32',
#   'names': ['left_shoulder_pan.pos',
#    'left_shoulder_lift.pos',
#    'left_elbow_flex.pos',
#    'left_wrist_flex.pos',
#    'left_wrist_roll.pos',
#    'left_gripper.pos',
#    'right_shoulder_pan.pos',
#    'right_shoulder_lift.pos',
#    'right_elbow_flex.pos',
#    'right_wrist_flex.pos',
#    'right_wrist_roll.pos',
#    'right_gripper.pos'],
#   'shape': (12,)},
#  'observation.images.top': {'dtype': 'video',
#   'shape': (480, 640, 3),
#   'names': ['height', 'width', 'channels'],
#   'info': {'video.height': 480,
#    'video.width': 640,
#    'video.codec': 'av1',
#    'video.pix_fmt': 'yuv420p',
#    'video.is_depth_map': False,
#    'video.fps': 30,
#    'video.channels': 3,
#    'has_audio': False}},
#  'observation.images.front': {'dtype': 'video',
#   'shape': (480, 640, 3),
#   'names': ['height', 'width', 'channels'],
#   'info': {'video.height': 480,
#    'video.width': 640,
#    'video.codec': 'av1',
#    'video.pix_fmt': 'yuv420p',
#    'video.is_depth_map': False,
#    'video.fps': 30,
#    'video.channels': 3,
#    'has_audio': False}},
#  'timestamp': {'dtype': 'float32', 'shape': (1,), 'names': None},
#  'frame_index': {'dtype': 'int64', 'shape': (1,), 'names': None},
#  'episode_index': {'dtype': 'int64', 'shape': (1,), 'names': None},
#  'index': {'dtype': 'int64', 'shape': (1,), 'names': None},
#  'task_index': {'dtype': 'int64', 'shape': (1,), 'names': None}}
